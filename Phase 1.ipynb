# %% [markdown]
# <h1>Predicting Airline Passenger Satisfaction</h1>
# <h2>Phase 1: Data Preparation & Visualisation</h2>

# %% [markdown]
# <h4>Group Name: Group 15</h4>
# <h5>Name: Evelyn Lie (s395110)</h5>
# <h5>Name: (s)</h5>
# <h5>Name: (s)</h5>
# <h5>Name: (s)</h5>

# %% [markdown]
# <h2>Table Of Contents</h2>
# <ul>
#     <li>Introduction</li>
#         <ul style = "list-style-type:square">
#             <li>Dataset Source</li>
#             <li>Dataset Details</li>
#             <li>Dataset Variables</li>
#             <li>Response Variables</li>
#         </ul>
#     <li>Goals and Objectives</li>
#     <li>Data Cleaning and Preprocessing</li>
#     <li>Data Exploration and Visualisation</li>
#     <li>Summary and Conclusion</li>
#     <li>References</li>
# </ul>

# %% [markdown]
# <h3>Introduction</h3>

# %% [markdown]
# <h4>Dataset Source</h4>

# %% [markdown]
# The Airline Passenger Satisfaction dataset used in study was sourced from Github (Akmand, 2022). This dataset contains the satisfaction rating of passengers who travels by plane.

# %% [markdown]
# <h4>Dataset Details</h4>

# %% [markdown]
# The dataset is about the the satisfaction rating of passengers travelling by plane and contains information about the customer type and age, type of travel, class, flight distance. Additional features included in this dataset are the gate location, seat comfortability, cleanliness, delay time of departure, delay time of arrival, check-in services, and in-flight services, such as wifi, entertainment, as well as food and drinks. These features seem to be sufficient for an attempt to predict the overall passenger satisfaction rating who travels by plane.
#
# This dataset has a total of 23 features and 129881 observations.

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import io
import requests

pd.set_option('display.max_columns', None) 

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'
plt.style.use("seaborn")

# %%
df_name = 'airline_passenger_satisfaction.csv'
df_url = 'https://raw.githubusercontent.com/akmand/datasets/main/airline_passenger_satisfaction.csv'
url_content = requests.get(df_url, verify = False).content
df = pd.read_csv(io.StringIO(url_content.decode('utf-8')))

df.sample(10, random_state=999)
# Out:
#         Gender      customer_type  age   type_of_travel customer_class  \
# 117352    Male     Loyal Customer   41  Business travel            Eco
# 75928     Male     Loyal Customer   38  Business travel       Business
# 26682     Male     Loyal Customer   36  Personal Travel            Eco
# 47086     Male     Loyal Customer   15  Personal Travel            Eco
# 95174     Male     Loyal Customer   65  Personal Travel            Eco
# 69597   Female     Loyal Customer   31  Business travel       Business
# 103699    Male     Loyal Customer   41  Business travel       Business
# 72511   Female     Loyal Customer   62  Business travel            Eco
# 2537      Male     Loyal Customer   53  Business travel       Business
# 122009    Male  disloyal Customer   29  Business travel            Eco
#
#         flight_distance  inflight_wifi_service  \
# 117352              996                      5
# 75928              3463                      5
# ...

# %% [markdown]
# <h4>Dataset Features</h4>
